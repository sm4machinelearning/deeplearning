# %%
from keras.datasets import boston_housing
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
# Out:
# ...
# 57344/57026 [==============================] - 0s 1us/step

# %%
print (x_train.shape)
print (x_train[0])
print (len(x_train[0]))
# Out:
# (404, 13)
# [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
# 13

# %%
print (y_train)
# Out:
# [15.2 42.3 50.  21.1 17.7 18.5 11.3 15.6 15.6 14.4 12.1 17.9 23.1 19.9
#  15.7  8.8 50.  22.5 24.1 27.5 10.9 30.8 32.9 24.  18.5 13.3 22.9 34.7
#  16.6 17.5 22.3 16.1 14.9 23.1 34.9 25.  13.9 13.1 20.4 20.  15.2 24.7
#  22.2 16.7 12.7 15.6 18.4 21.  30.1 15.1 18.7  9.6 31.5 24.8 19.1 22.
#  14.5 11.  32.  29.4 20.3 24.4 14.6 19.5 14.1 14.3 15.6 10.5  6.3 19.3
#  19.3 13.4 36.4 17.8 13.5 16.5  8.3 14.3 16.  13.4 28.6 43.5 20.2 22.
#  23.  20.7 12.5 48.5 14.6 13.4 23.7 50.  21.7 39.8 38.7 22.2 34.9 22.5
#  31.1 28.7 46.  41.7 21.  26.6 15.  24.4 13.3 21.2 11.7 21.7 19.4 50.
#  22.8 19.7 24.7 36.2 14.2 18.9 18.3 20.6 24.6 18.2  8.7 44.  10.4 13.2
#  21.2 37.  30.7 22.9 20.  19.3 31.7 32.  23.1 18.8 10.9 50.  19.6  5.
#  14.4 19.8 13.8 19.6 23.9 24.5 25.  19.9 17.2 24.6 13.5 26.6 21.4 11.9
#  22.6 19.6  8.5 23.7 23.1 22.4 20.5 23.6 18.4 35.2 23.1 27.9 20.6 23.7
#  28.  13.6 27.1 23.6 20.6 18.2 21.7 17.1  8.4 25.3 13.8 22.2 18.4 20.7
# ...

# %%
import numpy as np

mean, std = np.mean(x_train, axis=0), np.std(x_train, axis=0)

x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

print (x_train[0])
# Out:
# [-0.27224633 -0.48361547 -0.43576161 -0.25683275 -0.1652266  -0.1764426
#   0.81306188  0.1166983  -0.62624905 -0.59517003  1.14850044  0.44807713
#   0.8252202 ]

# %%
from keras import models
from keras import layers

def my_model(x_train):
  model = models.Sequential()
  model.add(layers.Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(16, activation='relu'))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
model = my_model(x_train)
for i in range(4):
  arr = np.arange(x_train.shape[0])
  v, t = arr[int(i*(len(arr))/4):int((i+1)*(len(arr))/4)], np.delete(arr, v)
  trainx, trainy = x_train[t], y_train[t]
  valx, valy = x_train[v], y_train[v]
  model.fit(trainx, trainy, epochs=500, batch_size=101, validation_data=(valx,valy))
# Out:
# Train on 303 samples, validate on 101 samples
# Epoch 1/500
# 303/303 [==============================] - 1s 2ms/step - loss: 542.6591 - mean_absolute_error: 21.5392 - val_loss: 549.0916 - val_mean_absolute_error: 21.2560
# Epoch 2/500
# 303/303 [==============================] - 0s 35us/step - loss: 520.4270 - mean_absolute_error: 21.0035 - val_loss: 527.0877 - val_mean_absolute_error: 20.7101
# Epoch 3/500
# 303/303 [==============================] - 0s 26us/step - loss: 498.1270 - mean_absolute_error: 20.4441 - val_loss: 501.4076 - val_mean_absolute_error: 20.0738
# Epoch 4/500
# 303/303 [==============================] - 0s 27us/step - loss: 472.9015 - mean_absolute_error: 19.7942 - val_loss: 474.2830 - val_mean_absolute_error: 19.3866
# Epoch 5/500
# 303/303 [==============================] - 0s 31us/step - loss: 446.7027 - mean_absolute_error: 19.1226 - val_loss: 446.4633 - val_mean_absolute_error: 18.6606
# Epoch 6/500
# ...

# %%
print (model.evaluate(x_test, y_test))
# Out:
# 102/102 [==============================] - 0s 58us/step
# [17.547316981296913, 2.989820639292399]
