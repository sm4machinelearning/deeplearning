# %%
import keras
from keras.datasets import reuters
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=None, test_split=0.2)
word_index = reuters.get_word_index()
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/reuters.npz
# 2113536/2110848 [==============================] - 1s 0us/step
# Downloading data from https://s3.amazonaws.com/text-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 0s 1us/step

# %%
print (x_train.shape)
print (len(x_train[0]))
print (x_train[0])
print (y_train.shape)
# Out:
# (8982,)
# 87
# [1, 27595, 28842, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]
# (8982,)

# %%
dict = []
for key, value in word_index.items():
  dict.append(key)

# %%
print (' '.join(dict[x] for x in x_train[0]))
print (' '.join(dict[x] for x in x_train[1]))
print (' '.join(dict[x] for x in x_train[2]))
# Out:
# fawc idic 725 refunding 300er passsengers eventual localized 271 feasibility precluding localized competing farmlands grains hat chevron india's stern chanthaburi steinweg localized wednesday modest sation wednesday lifeline four india's stern murchison 0053 690 272 chanthaburi affiliates hanging 27p refunding 919 stratabit suralco's 398 sation 395 sation adventist stipulate four 0053 stabilised stipulate four chanthaburi affiliates hermann australia's kanasa defaults sation rich sation sensitivity stipulate four 0053 yeo's shocks stipulate four grains refunding needed connection india's stern wagyu rudman suralco's 276 278 ceremenony sation menlo four broiler heublein
# fawc injection thsl articulation airline's slickline caracas exceed hermann slickline 684 roots loss localized ceasing doldrums botchwey 836 ceremenony highveld unpopular chanthaburi karachi 27p airline's minutes 345p injection thsl articulation refunding chanthaburi passsengers 5602 grains satisfactory wales committing wants localized hanging subdivisions airline's minutes practice practises chanthaburi affiliates dormancy bilzerian shocks errors become reimpose broiler heublein
# fawc affiliated heublein nature four tcby sensitivity 272 affiliated colombia's 278 luyten four tcby sensitivity 272 stratabit fashionable dnc stipulate tcby heublein amazing wooden competed turben lazere dnc stipulate tcby modest 278 stipulate rudman affiliated shocks friction four tcby wednesday 83p four affiliated colombia's perforations skepticism four tcby wednesday ceremenony four stratabit sanz 278 stipulate tcby 391 lme stipulate competed turben lazere shocks stipulate tcby modest wednesday stipulate fit chevron india's stern 24th hanging thassos screaming hudson's hawker corazon reiners climbed steinweg india's stern lichtbalu chinh inquiry wane quarter meteorologist pacemaker tnta monopoly sustaining screaming hanging indidate affiliates simplify 797 localized idly localized pyne chanthaburi fields loss localized lazere stipulate four hermann guayana genesis localized perforations evelyn wooden osp sigma localized pyne chanthaburi sugarcane bothered hodler localized ponomarev rebel stipulate hermann drag loss localized modest climbed stipulate broiler heublein

# %%
from keras.preprocessing.text import Tokenizer

max_words = 10000
num_classes = np.max(y_train) + 1

tokenizer = Tokenizer(num_words=max_words)
x_train = tokenizer.sequences_to_matrix(x_train, mode='binary')
x_test = tokenizer.sequences_to_matrix(x_test, mode='binary')
print (x_train.shape)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-af7a5dcebd7f> in <module>()
#       5
#       6 tokenizer = Tokenizer(num_words=max_words)
# ----> 7 x_train = tokenizer.sequences_to_matrix(x_train, mode='binary')
#       8 x_test = tokenizer.sequences_to_matrix(x_test, mode='binary')
#       9 print (x_train.shape)
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/text.py in sequences_to_matrix(self, sequences, mode)
#     410         x = np.zeros((len(sequences), num_words))
#     411         for i, seq in enumerate(sequences):
# --> 412             if not seq:
#     413                 continue
#     414             counts = defaultdict(int)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
